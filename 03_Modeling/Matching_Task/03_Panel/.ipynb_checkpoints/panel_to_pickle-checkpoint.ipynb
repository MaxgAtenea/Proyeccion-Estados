# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 50)

# %%
data = pd.read_excel("panel_estudiantes_V12_BDM20251015.xlsx")

# %%
data.head()
# Out:
#    DOCUMENTO  NIVEL_SISBEN_4    SEXO GRUPO_ETNICO       HIJOS  \
# 0     478541             NaN  HOMBRE     INDIGENA  SIN HIJOS
# 1     478541             NaN  HOMBRE     INDIGENA  SIN HIJOS
# 2     478541             NaN  HOMBRE     INDIGENA  SIN HIJOS
# 3     478541             NaN  HOMBRE     INDIGENA  SIN HIJOS
# 4     478541             NaN  HOMBRE     INDIGENA  SIN HIJOS
#
#    SABER11_PUNTAJE_GLOBAL  SNIES_IES  \
# 0                   303.0       3713
# 1                   303.0       3713
# 2                   303.0       3713
# 3                   303.0       3713
# 4                   303.0       3713
#
#                                           IES_NOMBRE  SNIES_PROGRAMA  \
# 0  FUNDACION UNIVERSITARIA PARA EL DESARROLLO HUM...           52198
# 1  FUNDACION UNIVERSITARIA PARA EL DESARROLLO HUM...           52198
# 2  FUNDACION UNIVERSITARIA PARA EL DESARROLLO HUM...           52198
# 3  FUNDACION UNIVERSITARIA PARA EL DESARROLLO HUM...           52198
# ...

# %%
data.to_pickle("panel_estudiantes_V12_BDM20251015.pkl")
